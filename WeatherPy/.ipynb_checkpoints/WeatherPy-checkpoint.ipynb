# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
from sklearn.linear_model import LinearRegression

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 637

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | selfoss
# Processing Record 3 of Set 1 | korla
# Processing Record 4 of Set 1 | tiksi
# Processing Record 5 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 6 of Set 1 | kingston
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | wailua homesteads
# Processing Record 9 of Set 1 | lerwick
# Processing Record 10 of Set 1 | edinburgh of the seven seas
# Processing Record 11 of Set 1 | sabang
# Processing Record 12 of Set 1 | shenkursk
# Processing Record 13 of Set 1 | vilyuchinsk
# Processing Record 14 of Set 1 | olonkinbyen
# Processing Record 15 of Set 1 | tanout
# Processing Record 16 of Set 1 | port-aux-francais
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | hawaiian paradise park
# Processing Record 19 of Set 1 | tazovsky
# Processing Record 20 of Set 1 | whitehorse
# Processing Record 21 of Set 1 | sur
# Processing Record 22 of Set 1 | pressbaum
# Processing Record 23 of Set 1 | joshimath
# Processing Record 24 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 25 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 26 of Set 1 | labuan
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | waitangi
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | norilsk
# Processing Record 31 of Set 1 | gornyy
# Processing Record 32 of Set 1 | sisimiut
# Processing Record 33 of Set 1 | kodiak
# Processing Record 34 of Set 1 | shengli
# Processing Record 35 of Set 1 | palikir - national government center
# Processing Record 36 of Set 1 | vila velha
# Processing Record 37 of Set 1 | sault ste. marie
# Processing Record 38 of Set 1 | san antonio de pale
# Processing Record 39 of Set 1 | mahalapye
# Processing Record 40 of Set 1 | klyuchi
# Processing Record 41 of Set 1 | ingeniero guillermo n. juarez
# Processing Record 42 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 1 | invercargill
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | susuman
# Processing Record 46 of Set 1 | ambovombe
# Processing Record 47 of Set 1 | udachny
# Processing Record 48 of Set 1 | uturoa
# Processing Record 49 of Set 1 | raduzhny
# Processing Record 50 of Set 1 | slave lake
# Processing Record 0 of Set 2 | puerto natales
# Processing Record 1 of Set 2 | keetmanshoop
# Processing Record 2 of Set 2 | titahari
# Processing Record 3 of Set 2 | pisco
# Processing Record 4 of Set 2 | malvan
# Processing Record 5 of Set 2 | watsa
# Processing Record 6 of Set 2 | praia da vitoria
# Processing Record 7 of Set 2 | vorgashor
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | cadale
# Processing Record 11 of Set 2 | atafu village
# Processing Record 12 of Set 2 | houghton
# Processing Record 13 of Set 2 | 'alaqahdari dishu
# Processing Record 14 of Set 2 | brownwood
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | camargo
# Processing Record 17 of Set 2 | afaahiti
# Processing Record 18 of Set 2 | adamstown
# Processing Record 19 of Set 2 | kuala belait
# Processing Record 20 of Set 2 | stanley
# Processing Record 21 of Set 2 | ascencion de guarayos
# City not found. Skipping...
# Processing Record 22 of Set 2 | usogorsk
# Processing Record 23 of Set 2 | khanty-mansiysk
# Processing Record 24 of Set 2 | nantucket
# Processing Record 25 of Set 2 | gevrai
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | saynshand
# Processing Record 28 of Set 2 | papatowai
# Processing Record 29 of Set 2 | bikenibeu village
# Processing Record 30 of Set 2 | arauco
# Processing Record 31 of Set 2 | polyarnyy
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | kencong
# Processing Record 34 of Set 2 | west island
# Processing Record 35 of Set 2 | liperi
# Processing Record 36 of Set 2 | aykhal
# Processing Record 37 of Set 2 | anloga
# Processing Record 38 of Set 2 | margaret river
# Processing Record 39 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 2 | slavyanka
# Processing Record 41 of Set 2 | hami
# Processing Record 42 of Set 2 | puerto ayora
# Processing Record 43 of Set 2 | kisangani
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | blackmans bay
# Processing Record 46 of Set 2 | palapye
# Processing Record 47 of Set 2 | shache
# Processing Record 48 of Set 2 | laojunmiao
# Processing Record 49 of Set 2 | bilibino
# Processing Record 0 of Set 3 | tralee
# Processing Record 1 of Set 3 | veraval
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | fisterra
# Processing Record 4 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 3 | weno
# Processing Record 6 of Set 3 | college
# Processing Record 7 of Set 3 | nemuro
# Processing Record 8 of Set 3 | burang
# Processing Record 9 of Set 3 | temiskaming shores
# Processing Record 10 of Set 3 | vaxjo
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | tromso
# Processing Record 15 of Set 3 | chadan
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | glenfield park
# Processing Record 18 of Set 3 | ma'rib
# Processing Record 19 of Set 3 | center
# Processing Record 20 of Set 3 | najran
# Processing Record 21 of Set 3 | santa ana de yacuma
# Processing Record 22 of Set 3 | dumai
# Processing Record 23 of Set 3 | san fernando de apure
# Processing Record 24 of Set 3 | manaure
# Processing Record 25 of Set 3 | nadi
# Processing Record 26 of Set 3 | inari
# Processing Record 27 of Set 3 | kone
# Processing Record 28 of Set 3 | porto novo
# Processing Record 29 of Set 3 | cambria
# Processing Record 30 of Set 3 | naze
# Processing Record 31 of Set 3 | remire-montjoly
# Processing Record 32 of Set 3 | boa vista
# Processing Record 33 of Set 3 | kurchum
# Processing Record 34 of Set 3 | betio village
# Processing Record 35 of Set 3 | lompoc
# Processing Record 36 of Set 3 | bardai
# Processing Record 37 of Set 3 | tobruk
# Processing Record 38 of Set 3 | karungdong
# Processing Record 39 of Set 3 | kultali
# City not found. Skipping...
# Processing Record 40 of Set 3 | colonia
# Processing Record 41 of Set 3 | bousso
# Processing Record 42 of Set 3 | jogbani
# Processing Record 43 of Set 3 | huarmey
# Processing Record 44 of Set 3 | jasper
# Processing Record 45 of Set 3 | linton
# Processing Record 46 of Set 3 | agat village
# Processing Record 47 of Set 3 | tanki leendert
# City not found. Skipping...
# Processing Record 48 of Set 3 | mincivan
# Processing Record 49 of Set 3 | lan sak
# Processing Record 0 of Set 4 | st. john's
# Processing Record 1 of Set 4 | tazacorte
# Processing Record 2 of Set 4 | cannonvale
# Processing Record 3 of Set 4 | bandar-e lengeh
# Processing Record 4 of Set 4 | pahrump
# Processing Record 5 of Set 4 | volokonovka
# Processing Record 6 of Set 4 | kuta
# Processing Record 7 of Set 4 | fort st. john
# Processing Record 8 of Set 4 | thinadhoo
# Processing Record 9 of Set 4 | muzaffarabad
# Processing Record 10 of Set 4 | carutapera
# Processing Record 11 of Set 4 | shahba
# Processing Record 12 of Set 4 | iskateley
# Processing Record 13 of Set 4 | bidur
# Processing Record 14 of Set 4 | mogocha
# Processing Record 15 of Set 4 | nguigmi
# Processing Record 16 of Set 4 | sovetskaya gavan'
# Processing Record 17 of Set 4 | shakawe
# Processing Record 18 of Set 4 | zeya
# Processing Record 19 of Set 4 | qamdo
# Processing Record 20 of Set 4 | la passe
# Processing Record 21 of Set 4 | ulaangom
# Processing Record 22 of Set 4 | chonchi
# Processing Record 23 of Set 4 | mont-laurier
# Processing Record 24 of Set 4 | taupo
# Processing Record 25 of Set 4 | umluj
# Processing Record 26 of Set 4 | grand falls-windsor
# Processing Record 27 of Set 4 | springbok
# Processing Record 28 of Set 4 | anna regina
# Processing Record 29 of Set 4 | syzran'
# Processing Record 30 of Set 4 | metro
# Processing Record 31 of Set 4 | parkes
# Processing Record 32 of Set 4 | coquimbo
# Processing Record 33 of Set 4 | callao
# Processing Record 34 of Set 4 | kerikeri
# Processing Record 35 of Set 4 | berezovyy
# Processing Record 36 of Set 4 | yorkton
# Processing Record 37 of Set 4 | sinabang
# Processing Record 38 of Set 4 | alamo
# Processing Record 39 of Set 4 | punta arenas
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | minas de marcona
# Processing Record 42 of Set 4 | lycksele
# Processing Record 43 of Set 4 | nar'yan-mar
# Processing Record 44 of Set 4 | savave village
# City not found. Skipping...
# Processing Record 45 of Set 4 | villa yapacani
# Processing Record 46 of Set 4 | bandarbeyla
# Processing Record 47 of Set 4 | namsos
# Processing Record 48 of Set 4 | kouango
# Processing Record 49 of Set 4 | anadyr
# Processing Record 0 of Set 5 | puerto colombia
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | kaa-khem
# Processing Record 4 of Set 5 | haiku-pauwela
# Processing Record 5 of Set 5 | crane
# Processing Record 6 of Set 5 | keflavik
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | balkashino
# Processing Record 9 of Set 5 | tual
# Processing Record 10 of Set 5 | mahajanga
# Processing Record 11 of Set 5 | vryburg
# Processing Record 12 of Set 5 | enewetak
# Processing Record 13 of Set 5 | richards bay
# Processing Record 14 of Set 5 | dhidhdhoo
# Processing Record 15 of Set 5 | whistler
# Processing Record 16 of Set 5 | aras-asan
# Processing Record 17 of Set 5 | vorkuta
# Processing Record 18 of Set 5 | ilulissat
# Processing Record 19 of Set 5 | dudinka
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | lockwood
# Processing Record 22 of Set 5 | gadzhiyevo
# Processing Record 23 of Set 5 | hithadhoo
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | bredasdorp
# Processing Record 26 of Set 5 | akureyri
# Processing Record 27 of Set 5 | constantia
# Processing Record 28 of Set 5 | lijiang
# Processing Record 29 of Set 5 | ghadamis
# Processing Record 30 of Set 5 | saranac lake
# Processing Record 31 of Set 5 | mahina
# Processing Record 32 of Set 5 | sibut
# Processing Record 33 of Set 5 | chegdomyn
# Processing Record 34 of Set 5 | mata-utu
# Processing Record 35 of Set 5 | las palmas de gran canaria
# Processing Record 36 of Set 5 | meadow lakes
# Processing Record 37 of Set 5 | rongelap
# Processing Record 38 of Set 5 | borskoye
# Processing Record 39 of Set 5 | udomlya
# Processing Record 40 of Set 5 | cherdyn'
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | broken hill
# Processing Record 43 of Set 5 | bella vista
# Processing Record 44 of Set 5 | kalmunai
# Processing Record 45 of Set 5 | lambarene
# Processing Record 46 of Set 5 | igarka
# Processing Record 47 of Set 5 | zaozersk
# Processing Record 48 of Set 5 | boise
# Processing Record 49 of Set 5 | king's lynn
# Processing Record 0 of Set 6 | changping
# Processing Record 1 of Set 6 | chibougamau
# Processing Record 2 of Set 6 | murghob
# Processing Record 3 of Set 6 | kapuskasing
# Processing Record 4 of Set 6 | kununurra
# Processing Record 5 of Set 6 | kittila
# Processing Record 6 of Set 6 | harper
# Processing Record 7 of Set 6 | labrador city
# Processing Record 8 of Set 6 | palmas
# Processing Record 9 of Set 6 | altai
# Processing Record 10 of Set 6 | ta`u
# Processing Record 11 of Set 6 | teluknaga
# Processing Record 12 of Set 6 | swakopmund
# Processing Record 13 of Set 6 | tindouf
# Processing Record 14 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 15 of Set 6 | bayji
# Processing Record 16 of Set 6 | merizo village
# Processing Record 17 of Set 6 | armidale
# Processing Record 18 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 6 | namibe
# Processing Record 20 of Set 6 | ulsteinvik
# Processing Record 21 of Set 6 | jamestown
# Processing Record 22 of Set 6 | yigo village
# Processing Record 23 of Set 6 | usinsk
# Processing Record 24 of Set 6 | borodulikha
# Processing Record 25 of Set 6 | reggane
# Processing Record 26 of Set 6 | santana
# Processing Record 27 of Set 6 | lazaro cardenas
# Processing Record 28 of Set 6 | toyooka
# Processing Record 29 of Set 6 | mar del plata
# Processing Record 30 of Set 6 | rio grande
# Processing Record 31 of Set 6 | salinas
# Processing Record 32 of Set 6 | georgetown
# Processing Record 33 of Set 6 | isafjordur
# Processing Record 34 of Set 6 | conceicao do araguaia
# Processing Record 35 of Set 6 | sankt veit an der glan
# Processing Record 36 of Set 6 | cidade velha
# Processing Record 37 of Set 6 | chu
# Processing Record 38 of Set 6 | ola
# Processing Record 39 of Set 6 | talagang
# Processing Record 40 of Set 6 | greymouth
# Processing Record 41 of Set 6 | bosobolo
# Processing Record 42 of Set 6 | lihue
# Processing Record 43 of Set 6 | tura
# Processing Record 44 of Set 6 | hadibu
# Processing Record 45 of Set 6 | palu
# Processing Record 46 of Set 6 | byron bay
# Processing Record 47 of Set 6 | yacuiba
# Processing Record 48 of Set 6 | codrington
# Processing Record 49 of Set 6 | lossiemouth
# Processing Record 0 of Set 7 | hasaki
# Processing Record 1 of Set 7 | leninskoye
# Processing Record 2 of Set 7 | uromi
# Processing Record 3 of Set 7 | inarajan village
# Processing Record 4 of Set 7 | port lincoln
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | utrik
# Processing Record 7 of Set 7 | labytnangi
# Processing Record 8 of Set 7 | floro
# Processing Record 9 of Set 7 | kupang
# Processing Record 10 of Set 7 | chavusy
# Processing Record 11 of Set 7 | nagqu
# Processing Record 12 of Set 7 | antsiranana
# Processing Record 13 of Set 7 | staroyur'yevo
# Processing Record 14 of Set 7 | vigan
# Processing Record 15 of Set 7 | srandakan
# Processing Record 16 of Set 7 | ciudad guayana
# Processing Record 17 of Set 7 | hobyo
# Processing Record 18 of Set 7 | mil'kovo
# Processing Record 19 of Set 7 | pionerskiy
# Processing Record 20 of Set 7 | neelankarai
# Processing Record 21 of Set 7 | jianshui
# Processing Record 22 of Set 7 | yuzhno-kurilsk
# Processing Record 23 of Set 7 | cassilandia
# Processing Record 24 of Set 7 | nhamunda
# Processing Record 25 of Set 7 | cable beach
# City not found. Skipping...
# Processing Record 26 of Set 7 | presque isle
# Processing Record 27 of Set 7 | tamanrasset
# Processing Record 28 of Set 7 | nuku'alofa
# Processing Record 29 of Set 7 | penjamo
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | zambezi
# Processing Record 32 of Set 7 | carnarvon
# Processing Record 33 of Set 7 | araguaina
# Processing Record 34 of Set 7 | kamiiso
# Processing Record 35 of Set 7 | yaren
# Processing Record 36 of Set 7 | kavali
# Processing Record 37 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 7 | taltal
# Processing Record 39 of Set 7 | fort bragg
# Processing Record 40 of Set 7 | mastic beach
# Processing Record 41 of Set 7 | igrim
# Processing Record 42 of Set 7 | sitia
# Processing Record 43 of Set 7 | shahrak
# Processing Record 44 of Set 7 | belmonte
# Processing Record 45 of Set 7 | gandi
# Processing Record 46 of Set 7 | bochum
# Processing Record 47 of Set 7 | ploneour-lanvern
# Processing Record 48 of Set 7 | luis correia
# Processing Record 49 of Set 7 | castillos
# Processing Record 0 of Set 8 | qingdao
# Processing Record 1 of Set 8 | ancud
# Processing Record 2 of Set 8 | luganville
# Processing Record 3 of Set 8 | tipasa
# Processing Record 4 of Set 8 | mancio lima
# Processing Record 5 of Set 8 | mahriz
# Processing Record 6 of Set 8 | howrah
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | itamaraca
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | nelidovo
# Processing Record 11 of Set 8 | liwale
# Processing Record 12 of Set 8 | icano
# Processing Record 13 of Set 8 | ghat
# Processing Record 14 of Set 8 | holly springs
# Processing Record 15 of Set 8 | arkalyk
# Processing Record 16 of Set 8 | juneau
# Processing Record 17 of Set 8 | gueltat zemmour
# City not found. Skipping...
# Processing Record 18 of Set 8 | grange
# Processing Record 19 of Set 8 | zilupe
# Processing Record 20 of Set 8 | melekeok village
# Processing Record 21 of Set 8 | mpika
# Processing Record 22 of Set 8 | collie
# Processing Record 23 of Set 8 | quellon
# Processing Record 24 of Set 8 | san fernando
# Processing Record 25 of Set 8 | bengkulu
# Processing Record 26 of Set 8 | abraham's bay
# City not found. Skipping...
# Processing Record 27 of Set 8 | nkurenkuru
# City not found. Skipping...
# Processing Record 28 of Set 8 | morogoro
# Processing Record 29 of Set 8 | corner brook
# Processing Record 30 of Set 8 | ifatsy
# City not found. Skipping...
# Processing Record 31 of Set 8 | guarapari
# Processing Record 32 of Set 8 | aginskoye
# Processing Record 33 of Set 8 | ebon
# Processing Record 34 of Set 8 | santa ana
# Processing Record 35 of Set 8 | suwayr
# Processing Record 36 of Set 8 | arkhangel'sk
# Processing Record 37 of Set 8 | port mathurin
# Processing Record 38 of Set 8 | genhe
# Processing Record 39 of Set 8 | hangu
# Processing Record 40 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 41 of Set 8 | cerro azul
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | lembar
# City not found. Skipping...
# Processing Record 44 of Set 8 | tabou
# Processing Record 45 of Set 8 | kodinsk
# Processing Record 46 of Set 8 | tulum
# Processing Record 47 of Set 8 | molepolole
# Processing Record 48 of Set 8 | uglegorsk
# Processing Record 49 of Set 8 | rurrenabaque
# Processing Record 0 of Set 9 | sandnessjoen
# Processing Record 1 of Set 9 | anacapri
# Processing Record 2 of Set 9 | hammerfest
# Processing Record 3 of Set 9 | cidreira
# Processing Record 4 of Set 9 | puerto deseado
# Processing Record 5 of Set 9 | auki
# Processing Record 6 of Set 9 | tshabong
# Processing Record 7 of Set 9 | new norfolk
# Processing Record 8 of Set 9 | glodeni
# Processing Record 9 of Set 9 | salekhard
# Processing Record 10 of Set 9 | tokar
# Processing Record 11 of Set 9 | lere
# Processing Record 12 of Set 9 | kuragino
# Processing Record 13 of Set 9 | puerto baquerizo moreno
# Processing Record 14 of Set 9 | nuuk
# Processing Record 15 of Set 9 | luderitz
# Processing Record 16 of Set 9 | bodaybo
# Processing Record 17 of Set 9 | deqen
# Processing Record 18 of Set 9 | kamyshlov
# Processing Record 19 of Set 9 | rondonopolis
# Processing Record 20 of Set 9 | borogontsy
# Processing Record 21 of Set 9 | klaksvik
# Processing Record 22 of Set 9 | broome
# Processing Record 23 of Set 9 | padang
# Processing Record 24 of Set 9 | newman
# Processing Record 25 of Set 9 | portales
# Processing Record 26 of Set 9 | bamboo flat
# Processing Record 27 of Set 9 | oborniki
# Processing Record 28 of Set 9 | kapa'a
# Processing Record 29 of Set 9 | shijiazhuang
# Processing Record 30 of Set 9 | santa cruz
# Processing Record 31 of Set 9 | aykol
# City not found. Skipping...
# Processing Record 32 of Set 9 | sola
# Processing Record 33 of Set 9 | ouesso
# Processing Record 34 of Set 9 | prestea
# Processing Record 35 of Set 9 | el abiodh sidi cheikh
# Processing Record 36 of Set 9 | kotlas
# Processing Record 37 of Set 9 | taoudenni
# Processing Record 38 of Set 9 | summerside
# Processing Record 39 of Set 9 | ciudad lazaro cardenas
# Processing Record 40 of Set 9 | baikonur
# Processing Record 41 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 42 of Set 9 | east brainerd
# Processing Record 43 of Set 9 | massawa
# Processing Record 44 of Set 9 | inda silase
# Processing Record 45 of Set 9 | ambon
# Processing Record 46 of Set 9 | i-n-salah
# Processing Record 47 of Set 9 | valledupar
# Processing Record 48 of Set 9 | rzepin
# Processing Record 49 of Set 9 | mount gambier
# Processing Record 0 of Set 10 | tetouan
# Processing Record 1 of Set 10 | christchurch
# Processing Record 2 of Set 10 | villa gesell
# Processing Record 3 of Set 10 | mangaratiba
# Processing Record 4 of Set 10 | coxen hole
# Processing Record 5 of Set 10 | urucui
# Processing Record 6 of Set 10 | axim
# Processing Record 7 of Set 10 | the pas
# Processing Record 8 of Set 10 | freeport
# Processing Record 9 of Set 10 | rikaze
# Processing Record 10 of Set 10 | bayanhongor
# Processing Record 11 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 12 of Set 10 | nykobing mors
# Processing Record 13 of Set 10 | huangnihe
# Processing Record 14 of Set 10 | brisas de zicatela
# Processing Record 15 of Set 10 | san bartolo de berrios
# City not found. Skipping...
# Processing Record 16 of Set 10 | lechinta
# Processing Record 17 of Set 10 | koungou
# Processing Record 18 of Set 10 | menongue
# Processing Record 19 of Set 10 | copala
# Processing Record 20 of Set 10 | am djarass
# City not found. Skipping...
# Processing Record 21 of Set 10 | kedougou
# Processing Record 22 of Set 10 | san benito
# Processing Record 23 of Set 10 | cine
# Processing Record 24 of Set 10 | saint-pierre
# Processing Record 25 of Set 10 | lorengau
# Processing Record 26 of Set 10 | pontianak
# Processing Record 27 of Set 10 | barentin
# Processing Record 28 of Set 10 | gaspe
# Processing Record 29 of Set 10 | pitoa
# Processing Record 30 of Set 10 | pundong
# Processing Record 31 of Set 10 | la ronge
# Processing Record 32 of Set 10 | birao
# Processing Record 33 of Set 10 | ixtapa
# Processing Record 34 of Set 10 | san pedro pochutla
# Processing Record 35 of Set 10 | cartagena del chaira
# Processing Record 36 of Set 10 | velingara
# Processing Record 37 of Set 10 | deqing
# Processing Record 38 of Set 10 | prince rupert
# Processing Record 39 of Set 10 | ballito
# Processing Record 40 of Set 10 | dhamar
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | kalispell
# Processing Record 43 of Set 10 | macapa
# Processing Record 44 of Set 10 | umm as sahik
# Processing Record 45 of Set 10 | alheim
# Processing Record 46 of Set 10 | muzayri'
# City not found. Skipping...
# Processing Record 47 of Set 10 | tadjourah
# Processing Record 48 of Set 10 | marsabit
# Processing Record 49 of Set 10 | bhimunipatnam
# Processing Record 0 of Set 11 | morant bay
# Processing Record 1 of Set 11 | salinopolis
# Processing Record 2 of Set 11 | fort-shevchenko
# Processing Record 3 of Set 11 | namtsy
# Processing Record 4 of Set 11 | east london
# Processing Record 5 of Set 11 | jerez de la frontera
# Processing Record 6 of Set 11 | north ward
# Processing Record 7 of Set 11 | ivdel'
# Processing Record 8 of Set 11 | port isabel
# Processing Record 9 of Set 11 | zima
# Processing Record 10 of Set 11 | plettenberg bay
# Processing Record 11 of Set 11 | acajutla
# Processing Record 12 of Set 11 | geraldton
# Processing Record 13 of Set 11 | pekalongan
# Processing Record 14 of Set 11 | onega
# Processing Record 15 of Set 11 | kiruna
# Processing Record 16 of Set 11 | sao jose da coroa grande
# Processing Record 17 of Set 11 | solwezi
# Processing Record 18 of Set 11 | princeville
# Processing Record 19 of Set 11 | santona
# Processing Record 20 of Set 11 | laguna
# Processing Record 21 of Set 11 | nuriootpa
# Processing Record 22 of Set 11 | olinda
# Processing Record 23 of Set 11 | ponta delgada
# Processing Record 24 of Set 11 | impfondo
# Processing Record 25 of Set 11 | port saint john's
# Processing Record 26 of Set 11 | nova sintra
# Processing Record 27 of Set 11 | gustine
# Processing Record 28 of Set 11 | borba
# Processing Record 29 of Set 11 | kolonia
# Processing Record 30 of Set 11 | taroa
# Processing Record 31 of Set 11 | vila do maio
# Processing Record 32 of Set 11 | thief river falls
# Processing Record 33 of Set 11 | lubango
# Processing Record 34 of Set 11 | si bun rueang
# Processing Record 35 of Set 11 | san sebastian de la gomera
# Processing Record 36 of Set 11 | badger
# Processing Record 37 of Set 11 | soio
# Processing Record 38 of Set 11 | lamu
# Processing Record 39 of Set 11 | magadan
# Processing Record 40 of Set 11 | sulak
# Processing Record 41 of Set 11 | jagannathpur
# Processing Record 42 of Set 11 | concepcion
# Processing Record 43 of Set 11 | flying fish cove
# Processing Record 44 of Set 11 | nebbi
# Processing Record 45 of Set 11 | guiuan
# Processing Record 46 of Set 11 | flin flon
# Processing Record 47 of Set 11 | martuk
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 0 of Set 12 | nizhnesortymskiy
# Processing Record 1 of Set 12 | verkhnevilyuysk
# Processing Record 2 of Set 12 | port augusta
# Processing Record 3 of Set 12 | huaihua
# Processing Record 4 of Set 12 | gallivare
# City not found. Skipping...
# Processing Record 5 of Set 12 | urengoy
# Processing Record 6 of Set 12 | ladismith
# City not found. Skipping...
# Processing Record 7 of Set 12 | quezon
# Processing Record 8 of Set 12 | frontera
# Processing Record 9 of Set 12 | dungannon
# Processing Record 10 of Set 12 | port shepstone
# Processing Record 11 of Set 12 | wielun
# Processing Record 12 of Set 12 | ifanadiana
# Processing Record 13 of Set 12 | estepona
# Processing Record 14 of Set 12 | cuite
# Processing Record 15 of Set 12 | celestun
# Processing Record 16 of Set 12 | puerto santa
# Processing Record 17 of Set 12 | bodo
# Processing Record 18 of Set 12 | puerto aysen
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | khandud
# Processing Record 21 of Set 12 | bantilan
# Processing Record 22 of Set 12 | huai'an
# Processing Record 23 of Set 12 | dwarka
# Processing Record 24 of Set 12 | arraial do cabo
# Processing Record 25 of Set 12 | kananga
# Processing Record 26 of Set 12 | yeppoon
# Processing Record 27 of Set 12 | aldinga beach
# Processing Record 28 of Set 12 | puerto armuelles
# Processing Record 29 of Set 12 | nouadhibou
# Processing Record 30 of Set 12 | phan rang-thap cham
# Processing Record 31 of Set 12 | rengo
# Processing Record 32 of Set 12 | coyhaique
# Processing Record 33 of Set 12 | dunedin
# Processing Record 34 of Set 12 | awjilah
# Processing Record 35 of Set 12 | taguatinga
# Processing Record 36 of Set 12 | el quebrachal
# Processing Record 37 of Set 12 | mangrol
# Processing Record 38 of Set 12 | mount isa
# Processing Record 39 of Set 12 | bongor
# Processing Record 40 of Set 12 | ouellah
# City not found. Skipping...
# Processing Record 41 of Set 12 | chui
# Processing Record 42 of Set 12 | aasiaat
# Processing Record 43 of Set 12 | cedeira
# Processing Record 44 of Set 12 | san jose village
# City not found. Skipping...
# Processing Record 45 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 46 of Set 12 | buckeye
# Processing Record 47 of Set 12 | villanueva
# Processing Record 48 of Set 12 | salym
# Processing Record 49 of Set 12 | hefei
# Processing Record 0 of Set 13 | waddan
# Processing Record 1 of Set 13 | neiafu
# Processing Record 2 of Set 13 | timimoun
# Processing Record 3 of Set 13 | abu dhabi
# Processing Record 4 of Set 13 | quila
# Processing Record 5 of Set 13 | binji
# Processing Record 6 of Set 13 | mitsamiouli
# Processing Record 7 of Set 13 | areia branca
# Processing Record 8 of Set 13 | melilla
# Processing Record 9 of Set 13 | kailua-kona
# Processing Record 10 of Set 13 | pemba
# Processing Record 11 of Set 13 | mokhsogollokh
# Processing Record 12 of Set 13 | micheweni
# Processing Record 13 of Set 13 | hotan
# Processing Record 14 of Set 13 | mingguang
# Processing Record 15 of Set 13 | punta del este
# Processing Record 16 of Set 13 | sijunjung
# Processing Record 17 of Set 13 | tadine
# Processing Record 18 of Set 13 | opuwo
# Processing Record 19 of Set 13 | harstad
# Processing Record 20 of Set 13 | vadso
# Processing Record 21 of Set 13 | lethem
# Processing Record 22 of Set 13 | kelmentsi
# Processing Record 23 of Set 13 | meknes
# Processing Record 24 of Set 13 | mercedes
# Processing Record 25 of Set 13 | pointe-du-lac
# Processing Record 26 of Set 13 | port blair
# Processing Record 27 of Set 13 | karratha
# Processing Record 28 of Set 13 | fairmont
# Processing Record 29 of Set 13 | culfa
# Processing Record 30 of Set 13 | antofagasta
# Processing Record 31 of Set 13 | eyl
# Processing Record 32 of Set 13 | shimokizukuri
# Processing Record 33 of Set 13 | alice springs
# Processing Record 34 of Set 13 | butembo
# Processing Record 35 of Set 13 | hisar
# Processing Record 36 of Set 13 | saint-louis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          606
# Lat           606
# Lng           606
# Max Temp      606
# Humidity      606
# Cloudiness    606
# Wind Speed    606
# Country       606
# Date          606
# dtype: int64

# %%
city_data_df['Max Temp'] = (city_data_df['Max Temp'] - 273.15) * 9/5 + 32
# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        grytviken -54.2811  -36.5092    36.032        97         100
# 1          selfoss  63.9331  -20.9971    50.036        61          86
# 2            korla  41.7597   86.1469    67.316        30          83
# 3            tiksi  71.6872  128.8694    26.564        85         100
# 4         kingston  17.9970  -76.7936    92.246        68          20
#
#          Wind Speed Country        Date  Max Temp (°F)
# City_ID
# 0              5.91      GS  1696263299         36.032
# 1              6.23      IS  1696263246         50.036
# 2              3.01      CN  1696263452         67.316
# 3              3.66      RU  1696263146         26.564
# 4              1.54      JM  1696263297         92.246

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        grytviken -54.2811  -36.5092    36.032        97         100
# 1          selfoss  63.9331  -20.9971    50.036        61          86
# 2            korla  41.7597   86.1469    67.316        30          83
# 3            tiksi  71.6872  128.8694    26.564        85         100
# 4         kingston  17.9970  -76.7936    92.246        68          20
#
#          Wind Speed Country        Date  Max Temp (°F)
# City_ID
# 0              5.91      GS  1696263299         36.032
# 1              6.23      IS  1696263246         50.036
# 2              3.01      CN  1696263452         67.316
# 3              3.66      RU  1696263146         26.564
# 4              1.54      JM  1696263297         92.246

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker ="o", edgecolors=["black"])

# Get the date 
date = pd.to_datetime(city_data_df["Date"][0], unit="s").strftime('%Y-%m-%d')

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (Date)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°F)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker ="o", edgecolors=["black"])

# Get the date 
date = pd.to_datetime(city_data_df["Date"][0], unit="s").strftime('%Y-%m-%d')

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (Date)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker ="o", edgecolors=["black"])

# Get the date 
date = pd.to_datetime(city_data_df["Date"][0], unit="s").strftime('%Y-%m-%d')

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (Date)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker ="o", edgecolors=["black"])

# Get the date 
date = pd.to_datetime(city_data_df["Date"][0], unit="s").strftime('%Y-%m-%d')

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (Date)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, xlabel, ylabel, title, text_coordinates):
    model = LinearRegression()
    
    x_values = x_values.values.reshape(-1, 1)
    model.fit(x_values, y_values)
    
    # Perform linear regression
    slope = model.coef_[0]
    intercept = model.intercept_
    regress_values = model.predict(x_values)
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    
    
    # Set labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    
    # Calculate the R-squared value
    r_squared = model.score(x_values, y_values)
    print(f"The R-squared is: {r_squared:.2f}")
    
    # Manually add the equation text to the plot
    equation_text = f'y = {slope:.2f}x + {intercept:.2f}'
    plt.text(x_values.min(), y_values.min(), equation_text, fontsize=12, color="red")
    
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1         selfoss  63.9331  -20.9971    50.036        61          86
# 2           korla  41.7597   86.1469    67.316        30          83
# 3           tiksi  71.6872  128.8694    26.564        85         100
# 4        kingston  17.9970  -76.7936    92.246        68          20
# 5        qaqortoq  60.7167  -46.0333    43.430        48         100
#
#          Wind Speed Country        Date  Max Temp (°F)
# City_ID
# 1              6.23      IS  1696263246         50.036
# 2              3.01      CN  1696263452         67.316
# 3              3.66      RU  1696263146         26.564
# 4              1.54      JM  1696263297         92.246
# 5              1.33      GL  1696263453         43.430

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                          grytviken -54.2811  -36.5092    36.032        97
# 8        edinburgh of the seven seas -37.0676  -12.3116    49.154        61
# 14                 port-aux-francais -49.3500   70.2167    33.512        59
# 15                           ushuaia -54.8000  -68.3000    41.054        59
# 24                          waitangi -43.9535 -176.5597    50.828        86
#
#          Cloudiness  Wind Speed Country        Date  Max Temp (°F)
# City_ID
# 0               100        5.91      GS  1696263299         36.032
# 8                81       11.77      SH  1696262928         49.154
# 14              100       15.24      TF  1696262956         33.512
# 15               96        2.72      AR  1696262923         41.054
# 24               98        4.47      NZ  1696262917         50.828

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Temperature vs. Latitude - Northern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.66

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Max Temp"], "Latitude", "Max Temperature (F)", "Linear Regression: Temperature vs. Latitude - Southern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.58

# %% [markdown]
# **Discussion about the linear relationship:**
#  - Negative slope in Northern Hemisphere: As you move north from the equator, Max Temperature tends to decrease.
#  - Positive slope in Southern Hemisphere: As you move south from the equator, Max Temperature tends to decrease.
#
# In both hemispheres, Latitude is a significant predictor of Max Temperature, with clear linear trends.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Humidity"], "Latitude", "Humidity", "Linear Regression: Humidity vs. Latitude - Northern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.02

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Humidity"], "Latitude", "Humidity", "Linear Regression: Humidity vs. Latitude - Southern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.00

# %% [markdown]
# **Discussion about the linear relationship:**
#  - In the Northern Hemisphere, there is a very weak positive linear relationship between Latitude and Humidity, but the relationship is not practically significant due to the low R-squared value.
#  - In the Southern Hemisphere, there is no meaningful linear relationship between Latitude and Humidity as indicated by both the low R-squared value and the nearly flat slope.
#
# These findings suggest that Latitude may not be a strong predictor of Humidity in either hemisphere, and other factors likely play a more significant role in determining Humidity levels.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Cloudiness vs. Latitude - Northern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.01

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Cloudiness"], "Latitude", "Cloudiness", "Linear Regression: Cloudiness vs. Latitude - Southern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.00

# %% [markdown]
# **Discussion about the linear relationship:**
#  - In the Northern Hemisphere, there is a very weak positive linear relationship between Latitude and Cloudiness, but the relationship is not practically significant due to the low R-squared value.
#  - In the Southern Hemisphere, there is no meaningful linear relationship between Latitude and Cloudiness, as indicated by both the low R-squared value and the nearly flat slope.
#
# These findings suggest that Latitude is not a strong predictor of Cloudiness in either hemisphere, and other factors likely have a more significant impact on Cloudiness levels.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"], northern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Wind Speed vs. Latitude - Northern Hemisphere", (10, 40))
# Out:
# The R-squared is: 0.02

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"], southern_hemi_df["Wind Speed"], "Latitude", "Wind Speed", "Linear Regression: Wind Speed vs. Latitude - Southern Hemisphere", (10, 20))
# Out:
# The R-squared is: 0.01

# %% [markdown]
# **Discussion about the linear relationship:**
#  - In both the Northern and Southern Hemispheres, there is a very weak linear relationship between Latitude and Wind Speed. The R-squared values are low, indicating that Latitude has limited explanatory power for Wind Speed in either hemisphere.
#  - The slopes in both hemispheres are close to zero, indicating that the change in Wind Speed with Latitude is minimal. While there is a slight positive trend in the Northern Hemisphere and a slight negative trend in the Southern Hemisphere, these trends are not practically significant.
#
# These findings suggest that Latitude is not a strong predictor of Wind Speed in either hemisphere, and other factors, such as local geography and weather patterns, likely have a more significant influence on Wind Speed.
